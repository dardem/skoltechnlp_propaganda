# %%
import sys
sys.path.append('/home/daryna/Documents/disser/semeval_propaganda2020')

from tools.markup_visualizer import MarkUpVisualizer
from tools.generate_all_articles_ids import generate_all_train_ids
from tools.tokenization import *
from IPython.display import display_html

# %%
articles_ids = generate_all_train_ids()

# %%
for article_id in articles_ids[:1]:
    tokens, positions, classes = tokenize_train(article_id, by_sentence=False,task_type='TC')
    display_html(MarkUpVisualizer.visualize_markup(tokens, classes,task_type='TC'))
# Out:
# <h3> Article: </h3><br><mark style='background-color: white'>Kavanaugh</mark> <mark style='background-color: white'> </mark> <mark style='background-color: white'>Nomination</mark> <mark style='background-color: white'> </mark> <mark style='background-color: white'>Is</mark> <mark style='background-color: white'> </mark> <mark style='background-color: DeepPink'>Exploding</mark> <mark style='background-color: DeepPink'> </mark> <mark style='background-color: DeepPink'>in</mark> <mark style='background-color: DeepPink'> </mark> <mark style='background-color: DeepPink'>Trump</mark> <mark style='background-color: DeepPink'>’</mark> <mark style='background-color: DeepPink'>s</mark> <mark style='background-color: DeepPink'> </mark> <mark style='background-color: DeepPink'>Face</mark> <mark style='background-color: white'>
# </mark> <mark style='background-color: white'>
# ...
